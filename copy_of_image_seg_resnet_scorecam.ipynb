# %%
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image
import numpy as np
import cv2
import os
from torch import nn

from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from tqdm import tqdm
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
# !pip install grad-cam
from pytorch_grad_cam import ScoreCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: grad-cam in /usr/local/lib/python3.12/dist-packages (1.5.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from grad-cam) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from grad-cam) (11.3.0)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from grad-cam) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.12/dist-packages (from grad-cam) (0.25.0+cu128)
# Requirement already satisfied: ttach in /usr/local/lib/python3.12/dist-packages (from grad-cam) (0.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from grad-cam) (4.67.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from grad-cam) (4.13.0.92)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from grad-cam) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from grad-cam) (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->grad-cam) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.7.1->grad-cam) (1.4.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->grad-cam) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->grad-cam) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->grad-cam) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->grad-cam) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.7.1->grad-cam) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.7.1->grad-cam) (3.0.3)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)



def preprocess_image(image, train=True):

    img = np.array(image)

    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

    l, a, b = cv2.split(img)

    clahe = cv2.createCLAHE(clipLimit=1.5)
    cl = clahe.apply(l)

    limg = cv2.merge((cl, a, b))
    img = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)

    image = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

    if train:

        transform = transforms.Compose([
            transforms.Resize((256,256)),
            transforms.RandomResizedCrop(224),
            transforms.RandomHorizontalFlip(),
             transforms.RandomVerticalFlip(),
            transforms.RandomRotation(15),
            transforms.ToTensor(),
            transforms.Normalize(
                mean=[0.485,0.456,0.406],
                std=[0.229,0.224,0.225]
            )

        ])

    else:

        transform = transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor(),
            transforms.Normalize(
                mean=[0.485,0.456,0.406],
                std=[0.229,0.224,0.225]
            )
        ])

    image_tensor = transform(image)

    return image_tensor
# Out:
# cuda

# %%
def collect_images(dataset_path):

    classes = sorted(os.listdir(dataset_path))
    class_to_idx = {c:i for i,c in enumerate(classes)}

    images = []

    valid_ext = (".jpg", ".jpeg", ".png")

    for c in classes:

        class_folder = os.path.join(dataset_path, c)

        for img in os.listdir(class_folder):

            if not img.lower().endswith(valid_ext):
                continue

            path = os.path.join(class_folder, img)

            images.append((path, class_to_idx[c]))

    return images, classes,class_to_idx

def extract_leaf_mask(image):
    """
    Isolates the leaf from the background.
    Returns the binary mask of the leaf and the total leaf area.
    """
    hsv_image=cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    LOWER_LEAF = np.array([15, 40, 40])
    UPPER_LEAF = np.array([95, 255, 255])

    # Spot detection thresholds


    KERNEL = np.ones((5, 5), np.uint8)
    # 1. Create a mask based on color range
    mask = cv2.inRange(hsv_image, LOWER_LEAF, UPPER_LEAF)

    # 2. Clean up noise using Morphological Closing
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, KERNEL)

    # 3. Find contours to identify distinct objects
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if not contours:
        return None, 0

    # 4. Keep only the largest contour (assuming it is the leaf)
    largest = max(contours, key=cv2.contourArea)

    # 5. Draw a clean mask of just the largest contour
    final_leaf_mask = np.zeros_like(mask)
    cv2.drawContours(final_leaf_mask, [largest], -1, 255, -1)

    leaf_area = cv2.countNonZero(final_leaf_mask)
    leaf = cv2.bitwise_and(image, image, mask=final_leaf_mask)
    return leaf, final_leaf_mask

# %%
class LeafDataset(Dataset):

    def __init__(self, data, train=True):

        self.data = data
        self.train = train

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):

        img_path, label = self.data[idx]

        with Image.open(img_path) as img:
            image = img.convert("RGB")

        image = preprocess_image(image, train=self.train)

        return image, label

# %%
# !unzip dataset_yolo2.zip
dataset_path="dataset_yolo2"

images, classes, class_to_idx = collect_images(dataset_path)
train_path = "dataset_yolo2/images/train"
val_path   = "dataset_yolo2/images/val"
test_path  = "dataset_yolo2/images/test"

train_data, classes, class_to_idx = collect_images(train_path)
val_data, _, _ = collect_images(val_path)
test_data, _, _ = collect_images(test_path)
labels = [label for _, label in train_data]

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(labels),
    y=labels
)

class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset_yolo2/images/val/healthy/ae0ad0c2-8693-4aff-8c4b-2f4d2d6f7f41___RS_HL 0454.JPG
#   inflating: dataset_yolo2/images/val/healthy/ae745e4a-eecc-40dd-b860-25bdee6729e3___GH_HL Leaf 417.2.JPG
#   inflating: dataset_yolo2/images/val/healthy/ae7d5e8e-5713-4eb8-b1e5-1ff3d2dba0a0___JR_HL 7708.JPG
#   inflating: dataset_yolo2/images/val/healthy/af15ac00-67ff-4114-ace8-6dca48b94665___RS_HL 1865.JPG
#   inflating: dataset_yolo2/images/val/healthy/af409ada-072e-4b27-ab15-5cd00116f82e___RS_HL 9824.JPG
#   inflating: dataset_yolo2/images/val/healthy/af83b40a-8cac-4467-a44b-1a129b25e4fc___GH_HL Leaf 362.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/af918bcc-6b43-40c6-b638-7294e3d64b52___JR_HL 8187.JPG
#   inflating: dataset_yolo2/images/val/healthy/b0bf12cb-8868-4762-bd27-8cb3ebf69594___GH_HL Leaf 512.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/b0c34863-3cd0-4699-86ea-3999a3350099___JR_HL 7563.JPG
#   inflating: dataset_yolo2/images/val/healthy/b0ea3617-be2a-4294-b547-3e341fbeb545___JR_HL 7786.JPG
#   inflating: dataset_yolo2/images/val/healthy/b0fe9fe9-52e7-40e4-b4c0-769f1a0c7fb9___RS_HL 4175.JPG
#   inflating: dataset_yolo2/images/val/healthy/b12059e3-404f-441a-9875-4af81aa3bd63___JR_HL 8570.JPG
#   inflating: dataset_yolo2/images/val/healthy/b1e628a8-b250-4ee7-9d3f-60f93a6a556b___RS_HL 0148.JPG
#   inflating: dataset_yolo2/images/val/healthy/b2045348-8e3f-408f-89c0-5546d59a3f9a___JR_HL 8370.JPG
#   inflating: dataset_yolo2/images/val/healthy/b2793705-a666-4ba0-ac9f-3b60fc0bbdf4___RS_HL 0342.JPG
#   inflating: dataset_yolo2/images/val/healthy/b2e63ab4-09d6-4b43-8767-6ce042e080b5___RS_HL 0309.JPG
#   inflating: dataset_yolo2/images/val/healthy/b353a9e6-cdab-4fb7-9a1f-8f25c14c0137___JR_HL 7795.JPG
#   inflating: dataset_yolo2/images/val/healthy/b3e24070-34b9-4dcb-8c84-026affadfb4b___GH_HL Leaf 360.JPG
#   inflating: dataset_yolo2/images/val/healthy/b3f3c64e-d3f1-42e9-9c6f-51ab8ab36a4d___JR_HL 7717.JPG
#   inflating: dataset_yolo2/images/val/healthy/b42621c3-f751-46e1-a8d2-83ed85b90554___RS_HL 1740.JPG
#   inflating: dataset_yolo2/images/val/healthy/b5142952-d782-4b4a-bf1b-db96da849191___RS_HL 0081.JPG
#   inflating: dataset_yolo2/images/val/healthy/b5453c78-26b4-40ef-a460-c878eb82fcea___RS_HL 9968.JPG
#   inflating: dataset_yolo2/images/val/healthy/b61b9d33-59ea-41b0-a554-c382eb6128c5___RS_HL 1919.JPG
#   inflating: dataset_yolo2/images/val/healthy/b6220cf3-e18d-4303-a7ed-cf60570bed93___JR_HL 5814.JPG
#   inflating: dataset_yolo2/images/val/healthy/b632d565-2883-4d01-a994-2068433bac08___RS_HL 9843.JPG
#   inflating: dataset_yolo2/images/val/healthy/b66ce067-f338-4ae5-8f62-578ce164456a___RS_HL 0610.JPG
#   inflating: dataset_yolo2/images/val/healthy/b7d4bf27-7ed1-4ba3-9b4b-8c9a8f19c4ee___JR_HL 8653.JPG
#   inflating: dataset_yolo2/images/val/healthy/b83ebe55-1008-4008-b6fb-582f61372abc___JR_HL 7622.JPG
#   inflating: dataset_yolo2/images/val/healthy/b840b04b-5909-4e35-beb8-7f53098975b1___RS_HL 0324.JPG
#   inflating: dataset_yolo2/images/val/healthy/b840daeb-319f-4cf3-b2a0-3010387fd5d3___GH_HL Leaf 493.JPG
#   inflating: dataset_yolo2/images/val/healthy/b8b8bef0-e86c-47ae-ba47-7912b10beffe___GH_HL Leaf 302.JPG
#   inflating: dataset_yolo2/images/val/healthy/b8ea8f49-ab54-4282-81f4-7d1497b4f818___JR_HL 5949.JPG
#   inflating: dataset_yolo2/images/val/healthy/b923ed54-63ad-49f8-8881-ebd654c5821c___RS_HL 0359.JPG
#   inflating: dataset_yolo2/images/val/healthy/b95435ea-5649-465e-83cc-247d1ab11b54___GH_HL Leaf 203.JPG
#   inflating: dataset_yolo2/images/val/healthy/ba527e73-8be2-4c53-9e5b-cafeab987bba___JR_HL 8037.JPG
#   inflating: dataset_yolo2/images/val/healthy/bab33032-182b-43c7-8eea-392267cd11ef___RS_HL 9822.JPG
#   inflating: dataset_yolo2/images/val/healthy/bad3b814-de59-4c37-8f47-00ed153f7e4f___RS_HL 0214.JPG
#   inflating: dataset_yolo2/images/val/healthy/bb06c1c7-3f4d-45d0-8882-b2eb8861b834___GH_HL Leaf 372.JPG
#   inflating: dataset_yolo2/images/val/healthy/bb7bfa73-7bd8-4703-a175-5843c00851ac___RS_HL 0517.JPG
#   inflating: dataset_yolo2/images/val/healthy/bb7e22d2-f187-4358-a78a-0ea71ecfadcb___RS_HL 9818.JPG
#   inflating: dataset_yolo2/images/val/healthy/bb8b0b14-a5f5-4c11-887f-71aed1864d84___GH_HL Leaf 409.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/bb9683d5-9302-4525-bd77-05153f65ffa3___RS_HL 0623.JPG
#   inflating: dataset_yolo2/images/val/healthy/bc0e8e3d-0cd4-4650-ac73-c099a0b75d4e___GH_HL Leaf 426.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/bc339a85-6c4e-428a-a18e-9174acdcab1e___RS_HL 0513.JPG
#   inflating: dataset_yolo2/images/val/healthy/bc388512-fc59-4069-bae0-05faca671d1e___JR_HL 8362.JPG
#   inflating: dataset_yolo2/images/val/healthy/bc6175c9-0e00-4618-af5a-3dd43a3e6266___GH_HL Leaf 238.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/bcae8241-335d-48f4-ae20-e57b17b29db4___RS_HL 0521.JPG
#   inflating: dataset_yolo2/images/val/healthy/bcf2a4c7-5e73-4443-b39c-74fd6895afb5___GH_HL Leaf 248.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/bd18b0d8-3ee7-4c96-a2d4-cf8db766c047___GH_HL Leaf 498.2.JPG
#   inflating: dataset_yolo2/images/val/healthy/bdba3ee1-95a1-45b8-9c31-21add45a86aa___JR_HL 8594.JPG
#   inflating: dataset_yolo2/images/val/healthy/be22f457-fd19-4d3d-9aa3-90a8e7f32ef9___JR_HL 8235.JPG
#   inflating: dataset_yolo2/images/val/healthy/be317686-2513-40b7-932f-e03795b0fbbd___JR_HL 5952.JPG
#   inflating: dataset_yolo2/images/val/healthy/be7c775f-b1d7-4a56-b815-afac3d69bd9e___JR_HL 7818.JPG
#   inflating: dataset_yolo2/images/val/healthy/beda9c8f-88eb-43c7-9670-60bd8fd5c43e___RS_HL 0038.JPG
#   inflating: dataset_yolo2/images/val/healthy/bf2e072b-f57b-48ce-b155-f255bebd85a2___GH_HL Leaf 317.JPG
#   inflating: dataset_yolo2/images/val/healthy/c02e2bda-f235-4538-b630-7af68169c8be___JR_HL 8388.JPG
#   inflating: dataset_yolo2/images/val/healthy/c0970a6a-0a3c-4582-99c1-1c2bf433b253___JR_HL 8757.JPG
#   inflating: dataset_yolo2/images/val/healthy/c0b3ea2d-4889-4693-8590-cef2d32b81e3___RS_HL 0370.JPG
#   inflating: dataset_yolo2/images/val/healthy/c0da16ab-82d4-4572-98a0-4bf4057fd6e4___JR_HL 8716.JPG
#   inflating: dataset_yolo2/images/val/healthy/c0ecb719-fde8-4003-98bd-b82c6162a5b2___JR_HL 8893.JPG
#   inflating: dataset_yolo2/images/val/healthy/c0f3838f-cfcd-45f7-8ba4-e7dab5519c62___JR_HL 8709.JPG
#   inflating: dataset_yolo2/images/val/healthy/c0f45b4c-fd37-4555-8e2f-4ab0f2622e6c___JR_HL 8546.JPG
#   inflating: dataset_yolo2/images/val/healthy/c0f919fb-1cbb-47e6-9308-87796ab6acac___JR_HL 8734.JPG
#   inflating: dataset_yolo2/images/val/healthy/c17aac7c-7e5c-4d2c-8699-9d1185a33eeb___JR_HL 8047.JPG
#   inflating: dataset_yolo2/images/val/healthy/c1aad9bf-ed08-4cb9-9ef0-8c0d4a3de010___GH_HL Leaf 319.JPG
#   inflating: dataset_yolo2/images/val/healthy/c1c04a55-0dd5-48e2-9cc6-76bbcc1899fd___GH_HL Leaf 340.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/c1dfd66e-7c0c-40a7-8280-0aa1aaf5436b___GH_HL Leaf 431.JPG
#   inflating: dataset_yolo2/images/val/healthy/c242dc1e-a2ab-4b51-8a81-0e6e1c8df833___JR_HL 7629.JPG
#   inflating: dataset_yolo2/images/val/healthy/c268e18a-6916-43ef-8aa8-f68b1429b7dc___GH_HL Leaf 236.2.JPG
#   inflating: dataset_yolo2/images/val/healthy/c277293d-bab5-433b-95d1-591ee60e1bd2___JR_HL 7793.JPG
#   inflating: dataset_yolo2/images/val/healthy/c2f44d15-cc56-44eb-afce-b53e919becb9___GH_HL Leaf 398.JPG
#   inflating: dataset_yolo2/images/val/healthy/c2f95f90-fac7-42e5-b6dd-789f8f2a50d9___JR_HL 8567.JPG
#   inflating: dataset_yolo2/images/val/healthy/c3449e24-b627-4a73-8e1a-ada5aeb1765d___JR_HL 8070.JPG
#   inflating: dataset_yolo2/images/val/healthy/c37309ec-1a0a-46e2-a777-e9cdae8ab18c___JR_HL 8183.JPG
#   inflating: dataset_yolo2/images/val/healthy/c40b106b-14bf-4af2-88b5-51182169d548___RS_HL 0298.JPG
#   inflating: dataset_yolo2/images/val/healthy/c488f861-d42c-4527-846d-1e352fbd72a3___JR_HL 5895.JPG
#   inflating: dataset_yolo2/images/val/healthy/c54a5152-b470-4037-ab1e-59b474c12fc6___RS_HL 9921.JPG
#   inflating: dataset_yolo2/images/val/healthy/c5db6d9e-4821-4b05-8b44-80ba702a8401___GH_HL Leaf 373.JPG
#   inflating: dataset_yolo2/images/val/healthy/c6111f5b-213f-4a67-bdda-7bb5af53c637___JR_HL 7637.JPG
#   inflating: dataset_yolo2/images/val/healthy/c6204cb3-cd9f-4d7b-92a6-9773fe562cab___RS_HL 1939.JPG
#   inflating: dataset_yolo2/images/val/healthy/c6acee22-6c56-41a8-ae90-26c6064e0261___GH_HL Leaf 468.JPG
#   inflating: dataset_yolo2/images/val/healthy/c704bd05-38e7-488a-9d97-d0cfccf1a5f8___JR_HL 8331.JPG
#   inflating: dataset_yolo2/images/val/healthy/c7a532ff-1b42-4a36-8207-646f8d71d994___RS_HL 0202.JPG
#   inflating: dataset_yolo2/images/val/healthy/c7f91fa4-3769-45ef-a494-1669ee62ee7a___RS_HL 9812.JPG
#   inflating: dataset_yolo2/images/val/healthy/c8337e7c-809b-4038-98c6-3144d1838c59___JR_HL 7686.JPG
#   inflating: dataset_yolo2/images/val/healthy/c8435849-38fc-453b-97d2-fee72dfb13b1___JR_HL 8132.JPG
#   inflating: dataset_yolo2/images/val/healthy/c86292c5-5f49-498d-9339-5f8d5d0b7492___JR_HL 7821.JPG
#   inflating: dataset_yolo2/images/val/healthy/c866865c-d239-48ff-9134-92df32fe972a___RS_HL 9791.JPG
#   inflating: dataset_yolo2/images/val/healthy/c90b9b00-dbfe-4481-b643-861fcd59c536___RS_HL 0598.JPG
#   inflating: dataset_yolo2/images/val/healthy/ca050e4b-ec58-4b88-a1be-980e908b84d4___RS_HL 0567.JPG
#   inflating: dataset_yolo2/images/val/healthy/ca45d0b4-76ba-47a7-950d-aed9f357c8f5___JR_HL 8351.JPG
#   inflating: dataset_yolo2/images/val/healthy/ca892e94-6f92-4676-bf0c-a81ee6eb8997___JR_HL 5827.JPG
#   inflating: dataset_yolo2/images/val/healthy/ca8ef249-eb56-438f-acf0-17e0104b16ec___JR_HL 8231.JPG
#   inflating: dataset_yolo2/images/val/healthy/ca9e9564-bf57-4e2e-837f-a847db99a316___GH_HL Leaf 401.JPG
#   inflating: dataset_yolo2/images/val/healthy/cac7a135-d3d1-4151-baa6-8288c6903423___JR_HL 7556.JPG
#   inflating: dataset_yolo2/images/val/healthy/cbd86fc5-7f88-4984-a1ed-445de8b76573___GH_HL Leaf 354.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/cbdca8a1-7822-472a-bc6f-a67a7a142dc0___JR_HL 8768.JPG
#   inflating: dataset_yolo2/images/val/healthy/cc2638ba-8ac3-4f48-9013-333648bb56c4___JR_HL 7986.JPG
#   inflating: dataset_yolo2/images/val/healthy/cc799066-155d-4d7d-9229-93db4e6be216___JR_HL 8421.JPG
#   inflating: dataset_yolo2/images/val/healthy/cc84d4e4-7e4e-499f-98b9-0987295b45cf___JR_HL 7572.JPG
#   inflating: dataset_yolo2/images/val/healthy/cc953a5e-f81b-4224-9690-c38ae63281bb___JR_HL 8579.JPG
#   inflating: dataset_yolo2/images/val/healthy/cdad1237-5d1e-46e8-a5fc-b0514aa994ab___JR_HL 8680.JPG
#   inflating: dataset_yolo2/images/val/healthy/ce081d63-8710-460f-9f20-cc67ef62fa37___RS_HL 9685.JPG
#   inflating: dataset_yolo2/images/val/healthy/ce303601-b655-483c-9778-3cbd317606be___RS_HL 0163.JPG
#   inflating: dataset_yolo2/images/val/healthy/ce56d8ec-bfd5-4755-8010-c42658f8d597___RS_HL 0090.JPG
#   inflating: dataset_yolo2/images/val/healthy/ce7d2ea8-c920-4ab0-a59c-807028c3baa6___JR_HL 8128.JPG
#   inflating: dataset_yolo2/images/val/healthy/ce9cef60-51af-4e89-bbe7-bf463d767e99___RS_HL 0614.JPG
#   inflating: dataset_yolo2/images/val/healthy/cebd3420-b698-43d1-a961-aeeb850a130f___JR_HL 8693.JPG
#   inflating: dataset_yolo2/images/val/healthy/cecbb89b-d8d9-4dbf-bf01-99021523c945___JR_HL 8629.JPG
#   inflating: dataset_yolo2/images/val/healthy/cfdcaf03-185a-4d36-9bd6-3256171b7c75___JR_HL 7667.JPG
#   inflating: dataset_yolo2/images/val/healthy/d001c6f1-3c5a-470b-b4a2-7996b9c68cd6___JR_HL 7695.JPG
#   inflating: dataset_yolo2/images/val/healthy/d15336df-9f16-4f8b-805f-d74f27af2735___RS_HL 9723.JPG
#   inflating: dataset_yolo2/images/val/healthy/d1750517-689b-4372-a717-6b81c0dd64b0___GH_HL Leaf 262.JPG
#   inflating: dataset_yolo2/images/val/healthy/d1752ed4-a0a7-4075-917d-205c0e785dcf___RS_HL 1911.JPG
#   inflating: dataset_yolo2/images/val/healthy/d1d360b8-26e7-413c-9863-e16d5087464d___JR_HL 7997.JPG
#   inflating: dataset_yolo2/images/val/healthy/d1dbb3ad-9839-4015-a4c8-9b562e196ac5___JR_HL 8347.JPG
#   inflating: dataset_yolo2/images/val/healthy/d212a7d8-8b14-4461-8cdd-d946cc366724___JR_HL 8360.JPG
#   inflating: dataset_yolo2/images/val/healthy/d270bd0e-c248-4bbd-8aa8-fd4a13351772___JR_HL 8346.JPG
#   inflating: dataset_yolo2/images/val/healthy/d287be3d-cac6-4485-8c31-674fb8b459be___RS_HL 1973.JPG
#   inflating: dataset_yolo2/images/val/healthy/d2faed98-e54a-42d4-8146-784b83c9ef9a___RS_HL 0545.JPG
#   inflating: dataset_yolo2/images/val/healthy/d30f0e3c-7246-455d-959c-6221eac22dfd___GH_HL Leaf 202.JPG
#   inflating: dataset_yolo2/images/val/healthy/d38fc068-8503-4868-9c57-8fba55a7892d___RS_HL 0293.JPG
#   inflating: dataset_yolo2/images/val/healthy/d3997d9d-f607-44f2-9473-b41db6b1116b___GH_HL Leaf 473.JPG
#   inflating: dataset_yolo2/images/val/healthy/d4091850-464c-4655-9edc-395f43c365e9___RS_HL 9657.JPG
#   inflating: dataset_yolo2/images/val/healthy/d442075f-73bb-47a0-9545-9b36bca9300b___GH_HL Leaf 210.JPG
#   inflating: dataset_yolo2/images/val/healthy/d454ff7e-7a9d-45c1-b7f1-d098edcb1fa7___RS_HL 0418.JPG
#   inflating: dataset_yolo2/images/val/healthy/d45c5eb7-c7b7-430b-9b2c-917a4a34315e___RS_HL 0151.JPG
#   inflating: dataset_yolo2/images/val/healthy/d4c014c8-81db-47ce-8a1a-277ef1159a3d___RS_HL 0211.JPG
#   inflating: dataset_yolo2/images/val/healthy/d520539e-4958-4a52-8b22-dc7714aa4039___JR_HL 8382.JPG
#   inflating: dataset_yolo2/images/val/healthy/d53448cd-ddd7-4dd6-a657-c60bde629130___RS_HL 0190.JPG
#   inflating: dataset_yolo2/images/val/healthy/d53487cf-1f9c-464a-bf4e-aff3277e85b3___JR_HL 7885.JPG
#   inflating: dataset_yolo2/images/val/healthy/d5633146-eac5-49e6-a6b4-8562aa7d1a1f___GH_HL Leaf 283.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/d670dc7a-8f79-477b-8cb3-170466f71667___JR_HL 8848.JPG
#   inflating: dataset_yolo2/images/val/healthy/d676d2f7-13a7-4d79-91fc-757b5d0bde6f___RS_HL 0601.JPG
#   inflating: dataset_yolo2/images/val/healthy/d688345e-4491-4f31-b2f4-d9111a12c2dd___GH_HL Leaf 288.JPG
#   inflating: dataset_yolo2/images/val/healthy/d6e06adc-15b1-4513-97b7-7e7b3920824f___JR_HL 8258.JPG
#   inflating: dataset_yolo2/images/val/healthy/d75ed8c7-610e-4abd-8a3a-a08993a92df3___GH_HL Leaf 323.2.JPG
#   inflating: dataset_yolo2/images/val/healthy/d7f13145-ea6d-4e04-9efa-669792d5e056___JR_HL 5980.JPG
#   inflating: dataset_yolo2/images/val/healthy/d81a234b-5eb3-42e3-b998-a7fb261178be___JR_HL 8007.JPG
#   inflating: dataset_yolo2/images/val/healthy/d84b65fd-6841-435f-9c9f-2ba8afe2f62a___RS_HL 0541.JPG
#   inflating: dataset_yolo2/images/val/healthy/d84eb3b6-3321-4034-9bcc-d2cddb8a3467___RS_HL 0053.JPG
#   inflating: dataset_yolo2/images/val/healthy/d8ce2a81-c366-4a88-bde3-ee9a98e1e30c___RS_HL 0036.JPG
#   inflating: dataset_yolo2/images/val/healthy/d8e3f7ec-b032-4e15-b593-895d1299cb4f___JR_HL 8377.JPG
#   inflating: dataset_yolo2/images/val/healthy/d93007b0-adaa-43d4-80be-d796d59944e6___JR_HL 7683.JPG
#   inflating: dataset_yolo2/images/val/healthy/da3e3bf7-80da-479b-99f1-f86f18d8a264___GH_HL Leaf 511.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/da5c938a-1baf-46cb-b1e6-c3bfef99b816___RS_HL 9981.JPG
#   inflating: dataset_yolo2/images/val/healthy/da6be4a5-51ff-4bea-894e-9c5d1d3f699d___JR_HL 8205.JPG
#   inflating: dataset_yolo2/images/val/healthy/da7db6e5-d5d5-489a-b1b2-9b3a880cebaa___RS_HL 9769.JPG
#   inflating: dataset_yolo2/images/val/healthy/da84d53c-1306-4823-99b5-abfe3e184b7f___JR_HL 7691.JPG
#   inflating: dataset_yolo2/images/val/healthy/daa4e664-5ec5-4349-b8de-0673cdfe374d___GH_HL Leaf 168.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/db39cf0e-cfe0-49d1-a5ed-5d69faa26507___JR_HL 8756.JPG
#   inflating: dataset_yolo2/images/val/healthy/dbadea40-bbdf-48e3-a5ad-7f78d2f335e0___JR_HL 8028.JPG
#   inflating: dataset_yolo2/images/val/healthy/dbe9b4f1-d676-42fc-abca-8cf6fe58eda7___JR_HL 8516.JPG
#   inflating: dataset_yolo2/images/val/healthy/dc16830f-b977-49cc-808b-9b1432a047a2___JR_HL 5925.JPG
#   inflating: dataset_yolo2/images/val/healthy/dc51f65e-d2d7-43f1-be27-063700a89eba___RS_HL 9951.JPG
#   inflating: dataset_yolo2/images/val/healthy/dc7bc940-f9ee-48ae-82da-3e8921e8b298___JR_HL 5831.JPG
#   inflating: dataset_yolo2/images/val/healthy/dc962f4d-1d6a-4304-8977-2925bae01f00___JR_HL 8564.JPG
#   inflating: dataset_yolo2/images/val/healthy/dd056f7a-fcba-4f1a-b45c-f06da72c4f02___JR_HL 8012.JPG
#   inflating: dataset_yolo2/images/val/healthy/dd7d8e47-35f8-4c97-900b-f095694c38ed___GH_HL Leaf 313.JPG
#   inflating: dataset_yolo2/images/val/healthy/dd87648b-f981-45cc-828c-f4a4634630c9___JR_HL 8186.JPG
#   inflating: dataset_yolo2/images/val/healthy/dddbe84f-16f2-42ba-ab89-1b3aad6b9658___JR_HL 7590.JPG
#   inflating: dataset_yolo2/images/val/healthy/de022e24-cd3f-4bf0-a009-85ee86f75bb6___JR_HL 7651.JPG
#   inflating: dataset_yolo2/images/val/healthy/de357e36-5be1-4e18-a590-77436b295089___JR_HL 8430.JPG
#   inflating: dataset_yolo2/images/val/healthy/de914baa-f72d-4cbf-a9fd-a60baf466e06___GH_HL Leaf 450.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/dea347a1-4303-48e1-8db0-997d084e6bd0___RS_HL 9724.JPG
#   inflating: dataset_yolo2/images/val/healthy/decd2c69-c302-461a-a2f7-7c1e37d9d633___RS_HL 0258.JPG
#   inflating: dataset_yolo2/images/val/healthy/ded136b7-be9e-4aad-9150-5318d6002a59___JR_HL 5856.JPG
#   inflating: dataset_yolo2/images/val/healthy/df53547e-28ef-4619-8b01-aa2d50e6c8b3___JR_HL 8733.JPG
#   inflating: dataset_yolo2/images/val/healthy/df5a72ad-2928-4bcb-81d8-cfb85a3186a2___JR_HL 8243.JPG
#   inflating: dataset_yolo2/images/val/healthy/df7005ca-2252-470b-aba5-e1eb43bb468e___JR_HL 5916.JPG
#   inflating: dataset_yolo2/images/val/healthy/dfe76f2d-7086-4c4c-9f6c-a6af6b666dee___JR_HL 7714.JPG
#   inflating: dataset_yolo2/images/val/healthy/dfeb1e66-f94b-4ad4-9ad3-ba50d9ac1a2d___JR_HL 7752.JPG
#   inflating: dataset_yolo2/images/val/healthy/e00c6d8e-1363-4e9e-a30f-58c8972b1272___JR_HL 7636.JPG
#   inflating: dataset_yolo2/images/val/healthy/e020155a-f93a-496c-adc6-1810b4cea333___GH_HL Leaf 206.JPG
#   inflating: dataset_yolo2/images/val/healthy/e03f89bc-a4ab-4afe-b25a-590fa91f1d28___JR_HL 8695.JPG
#   inflating: dataset_yolo2/images/val/healthy/e0d2d9f6-b29e-4cd8-8c2b-7d462271ceb3___RS_HL 9787.JPG
#   inflating: dataset_yolo2/images/val/healthy/e12936ac-7354-434c-b857-1e742e383dd5___RS_HL 9878.JPG
#   inflating: dataset_yolo2/images/val/healthy/e18c0617-2154-4a2c-a1e6-f649fdb4db59___JR_HL 7755.JPG
#   inflating: dataset_yolo2/images/val/healthy/e1b69d9c-2827-497f-9ff5-fb0908720a7e___JR_HL 8505.JPG
#   inflating: dataset_yolo2/images/val/healthy/e225eb60-d018-4014-a4f5-eadd0aad06ef___GH_HL Leaf 438.JPG
#   inflating: dataset_yolo2/images/val/healthy/e25bc3a8-dd00-4c02-9f4e-81e6cf682729___RS_HL 0101.JPG
#   inflating: dataset_yolo2/images/val/healthy/e2895bd7-f8f5-46ea-86b1-d90fe9bc0800___JR_HL 8254.JPG
#   inflating: dataset_yolo2/images/val/healthy/e2f520b1-ac21-445b-9a3f-cb6e506e3044___RS_HL 0381.JPG
#   inflating: dataset_yolo2/images/val/healthy/e336eb74-a19d-4461-871e-3124c5e0d047___RS_HL 0558.JPG
#   inflating: dataset_yolo2/images/val/healthy/e33a35bb-e830-470d-be7e-f21b136ab6bf___JR_HL 5894.JPG
#   inflating: dataset_yolo2/images/val/healthy/e33cde2d-5103-48aa-bb82-490aa779312c___GH_HL Leaf 515.2.JPG
#   inflating: dataset_yolo2/images/val/healthy/e34510f2-0d40-4385-a73f-f32317d24b59___JR_HL 7874.JPG
#   inflating: dataset_yolo2/images/val/healthy/e531e3da-a55b-41a9-8700-3e163226bfb2___GH_HL Leaf 188.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/e53267d6-9a69-4e42-9ddc-8481a337b3e0___RS_HL 0073.JPG
#   inflating: dataset_yolo2/images/val/healthy/e55fc417-6c08-4150-913e-11e7c7e15eb7___RS_HL 0504.JPG
#   inflating: dataset_yolo2/images/val/healthy/e59d735a-0312-46e4-943a-2262ea2cd502___RS_HL 0428.JPG
#   inflating: dataset_yolo2/images/val/healthy/e623a5a9-edc8-4c81-ada4-68b3ebadfc7e___RS_HL 0082.JPG
#   inflating: dataset_yolo2/images/val/healthy/e62a7ec8-3e5e-4a47-be14-a57db0322bb6___RS_HL 9627.JPG
#   inflating: dataset_yolo2/images/val/healthy/e64cc93e-5968-4cec-9ded-9dd9c0ae4ae1___JR_HL 8518.JPG
#   inflating: dataset_yolo2/images/val/healthy/e6584f1d-9338-4807-a2f2-8c0a70220c22___GH_HL Leaf 239.JPG
#   inflating: dataset_yolo2/images/val/healthy/e67fdf04-f0a3-4351-b65d-a1b7362fc032___GH_HL Leaf 304.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/e693354a-053c-4093-8642-cc8f5f9eb2cc___RS_HL 1746.JPG
#   inflating: dataset_yolo2/images/val/healthy/e6a3e0cb-e1d4-4440-9440-f0b4f489ecc4___JR_HL 8742.JPG
#   inflating: dataset_yolo2/images/val/healthy/e6d12c88-7d13-4b26-ada8-c5b34ccc77a5___RS_HL 0435.JPG
#   inflating: dataset_yolo2/images/val/healthy/e786ac89-29fe-47e3-b49e-b9a9ee7edd9d___GH_HL Leaf 342.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/e7a9a772-95f5-4bd4-ad34-831c3c47c024___RS_HL 9909.JPG
#   inflating: dataset_yolo2/images/val/healthy/e7ab090d-f32a-46c2-b3a2-919d76437fee___RS_HL 0207.JPG
#   inflating: dataset_yolo2/images/val/healthy/e7d07408-70bb-421d-9224-df4961a01cb9___GH_HL Leaf 509.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/e7d0f9a3-f28d-4c66-aba7-ce7c831590f5___JR_HL 8249.JPG
#   inflating: dataset_yolo2/images/val/healthy/e8d0f3de-312b-4316-aca4-798a51ebd423___GH_HL Leaf 520.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/e921cedb-b111-45d5-9dce-ce03a785fd27___JR_HL 7994.JPG
#   inflating: dataset_yolo2/images/val/healthy/e969c25d-8cc4-4730-a65b-330cd4d38c9a___GH_HL Leaf 427.JPG
#   inflating: dataset_yolo2/images/val/healthy/ea5402e9-f5e9-450c-bef6-f9d0bb544e68___JR_HL 5873.JPG
#   inflating: dataset_yolo2/images/val/healthy/eaac4a8f-7e24-4bfd-96ce-52eb4339772e___JR_HL 7597.JPG
#   inflating: dataset_yolo2/images/val/healthy/eab401a8-c014-4a63-98d4-b6144cfc7bc9___GH_HL Leaf 289.JPG
#   inflating: dataset_yolo2/images/val/healthy/eb0b95d9-4012-494c-85b6-48f7e250c958___GH_HL Leaf 404.JPG
#   inflating: dataset_yolo2/images/val/healthy/eb2c25bd-b896-45f1-b3a2-7ca6b78c219d___GH_HL Leaf 351.JPG
#   inflating: dataset_yolo2/images/val/healthy/ec094cc1-d95c-4fb5-8b21-3afcfbe39ea2___JR_HL 7765.JPG
#   inflating: dataset_yolo2/images/val/healthy/ec1bfc74-550b-4478-95c0-d60c1379957a___RS_HL 9879.JPG
#   inflating: dataset_yolo2/images/val/healthy/ec2ace5b-0368-4012-a46e-21236926193c___RS_HL 0086.JPG
#   inflating: dataset_yolo2/images/val/healthy/ec363e4b-79c9-460a-a6a4-cac25a71d6ba___JR_HL 8478.JPG
#   inflating: dataset_yolo2/images/val/healthy/ecce81e3-9bcc-4bec-9adf-81e9f96cf953___JR_HL 8216.JPG
#   inflating: dataset_yolo2/images/val/healthy/ecf64cfc-d521-48af-bb48-06edc78074c5___GH_HL Leaf 323.JPG
#   inflating: dataset_yolo2/images/val/healthy/ed4e4d41-ed9d-4e62-9cc8-33fadd791847___RS_HL 0338.JPG
#   inflating: dataset_yolo2/images/val/healthy/ee052892-e935-4fbb-9344-4d23c57c6890___RS_HL 5400.JPG
#   inflating: dataset_yolo2/images/val/healthy/ee0dd8c0-8db2-4eff-8e4d-76cb146f2b34___GH_HL Leaf 166.2.JPG
#   inflating: dataset_yolo2/images/val/healthy/ee3ec69a-f2a4-42f2-90e1-121db2f97e42___JR_HL 8164.JPG
#   inflating: dataset_yolo2/images/val/healthy/ee4400a9-c4f6-432d-985a-ff8dc730467b___JR_HL 7620.JPG
#   inflating: dataset_yolo2/images/val/healthy/ee9a0425-e0ff-4ecc-809f-da248151c841___JR_HL 8880.JPG
#   inflating: dataset_yolo2/images/val/healthy/eed1b6d4-c01c-4b3f-8aba-77ebc730b2f9___JR_HL 7907.JPG
#   inflating: dataset_yolo2/images/val/healthy/ef21da16-050f-4be8-a91f-e1fa13ce3991___RS_HL 0242.JPG
#   inflating: dataset_yolo2/images/val/healthy/ef492a6d-0db4-4fb5-b513-12a262215f00___RS_HL 9638.JPG
#   inflating: dataset_yolo2/images/val/healthy/efdafba8-8b81-462a-83d6-7b064ed28a4d___JR_HL 8228.JPG
#   inflating: dataset_yolo2/images/val/healthy/f0037c61-001d-4b1f-b794-5b5ab49d50d5___RS_HL 0527.JPG
#   inflating: dataset_yolo2/images/val/healthy/f025d161-089c-49e4-8f42-ca979e430977___JR_HL 6012.JPG
#   inflating: dataset_yolo2/images/val/healthy/f02b5ae2-2313-481b-8347-09459952aada___JR_HL 7894.JPG
#   inflating: dataset_yolo2/images/val/healthy/f0336650-0021-43e9-9e8c-d921c5532116___RS_HL 0249.JPG
#   inflating: dataset_yolo2/images/val/healthy/f04f1e27-b6b0-43a6-b5c5-a4ec6d75ed3e___RS_HL 9737.JPG
#   inflating: dataset_yolo2/images/val/healthy/f0cc7028-bf33-4ed4-8df0-7f1e80f42d15___GH_HL Leaf 266.JPG
#   inflating: dataset_yolo2/images/val/healthy/f0e93256-3b10-43c9-880e-e041de89502c___JR_HL 5846.JPG
#   inflating: dataset_yolo2/images/val/healthy/f1e20811-da4e-4f0f-b8ee-f325d90f6481___RS_HL 0084.JPG
#   inflating: dataset_yolo2/images/val/healthy/f24f1078-123e-4c89-bba8-2e1f7cf264bb___JR_HL 8196.JPG
#   inflating: dataset_yolo2/images/val/healthy/f2eeb551-94e8-4ac2-a5de-4702e6349f42___JR_HL 8761.JPG
#   inflating: dataset_yolo2/images/val/healthy/f2f5162b-7cc7-4315-8692-d1eaab98c554___GH_HL Leaf 507.2.JPG
#   inflating: dataset_yolo2/images/val/healthy/f30983c0-6e20-43cc-8672-4622ca34c830___RS_HL 1949.JPG
#   inflating: dataset_yolo2/images/val/healthy/f32a71f9-5468-4169-aa2f-e895f070bfc7___RS_HL 9997.JPG
#   inflating: dataset_yolo2/images/val/healthy/f42a7c9b-92e0-461b-b470-463a6f0b7aff___JR_HL 8747.JPG
#   inflating: dataset_yolo2/images/val/healthy/f433b7ce-cddb-4f22-8b0f-2376789c45f1___GH_HL Leaf 337.JPG
#   inflating: dataset_yolo2/images/val/healthy/f460de9c-14ab-4bac-8cb6-b25c958ae78f___JR_HL 8596.JPG
#   inflating: dataset_yolo2/images/val/healthy/f48aed97-8db4-40a5-aa39-e2c3c70fe8be___GH_HL Leaf 524.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/f4be3632-42a1-415a-9f7e-1d5ecb9f49d7___RS_HL 1783.JPG
#   inflating: dataset_yolo2/images/val/healthy/f5252d99-6752-457b-b430-965d545d3b41___RS_HL 0412.JPG
#   inflating: dataset_yolo2/images/val/healthy/f54a5053-dca2-4460-bd8d-27be3eb1e9b4___GH_HL Leaf 495.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/f5e369a3-421e-43b9-ab00-840e7535a5eb___JR_HL 8076.JPG
#   inflating: dataset_yolo2/images/val/healthy/f60f6c8b-54f7-4002-b26d-636037912c4d___RS_HL 9956.JPG
#   inflating: dataset_yolo2/images/val/healthy/f6202c30-deb0-498d-8e49-44b012204547___JR_HL 8127.JPG
#   inflating: dataset_yolo2/images/val/healthy/f63db177-4ffc-421f-b164-48f6a22dd14a___JR_HL 8169.JPG
#   inflating: dataset_yolo2/images/val/healthy/f66af6c0-6fc6-4020-b1de-a73685d497c2___RS_HL 4181.JPG
#   inflating: dataset_yolo2/images/val/healthy/f6884753-9a44-4f1c-a99b-ef40faa2df5a___RS_HL 0492.JPG
#   inflating: dataset_yolo2/images/val/healthy/f6a5a9a3-f9a6-4fad-83c3-2ce3e8618b52___RS_HL 0169.JPG
#   inflating: dataset_yolo2/images/val/healthy/f6cf7e4b-5a82-4383-818d-f68c887fb2c2___JR_HL 7746.JPG
#   inflating: dataset_yolo2/images/val/healthy/f6f43f0f-592b-4e5a-9a34-73856a4a8571___JR_HL 5988.JPG
#   inflating: dataset_yolo2/images/val/healthy/f822e8d5-6cb7-40ad-a6ce-b92105e7ce03___JR_HL 7905.JPG
#   inflating: dataset_yolo2/images/val/healthy/fb123526-11fd-4d0d-96cc-3423da0b61a2___RS_HL 9756.JPG
#   inflating: dataset_yolo2/images/val/healthy/fb4468f7-1a89-496a-8953-32edb1ff775a___JR_HL 8888.JPG
#   inflating: dataset_yolo2/images/val/healthy/fb6f5d31-176f-4694-9178-0732fb1efcf5___JR_HL 5868.JPG
#   inflating: dataset_yolo2/images/val/healthy/fc1e8e1c-5939-4ad9-b87e-2cbb77cef418___RS_HL 0536.JPG
#   inflating: dataset_yolo2/images/val/healthy/fc849a80-15fd-486d-bedc-0239e1278660___RS_HL 0494.JPG
#   inflating: dataset_yolo2/images/val/healthy/fc896bf4-d52b-494e-ae5f-ab18d00f2cd7___JR_HL 8343.JPG
#   inflating: dataset_yolo2/images/val/healthy/fcc91cef-9892-4eb2-a3f0-36bdc4e11f59___JR_HL 7687.JPG
#   inflating: dataset_yolo2/images/val/healthy/fd061d12-644d-4ac5-a0b5-2e88469e506b___GH_HL Leaf 414.JPG
#   inflating: dataset_yolo2/images/val/healthy/fd09836b-96be-498a-a720-e17a54522de7___RS_HL 9687.JPG
#   inflating: dataset_yolo2/images/val/healthy/fd1db002-680b-432b-9d60-68b80a4a310f___RS_HL 0049.JPG
#   inflating: dataset_yolo2/images/val/healthy/fd27de23-27cd-4f09-a962-df0b26899b07___RS_HL 0039.JPG
#   inflating: dataset_yolo2/images/val/healthy/fd2fa9cc-2147-40ff-9e71-0056eb7884ed___GH_HL Leaf 285.JPG
#   inflating: dataset_yolo2/images/val/healthy/fd4cbc98-dde3-45ce-b794-f6b037eed2b9___JR_HL 7606.JPG
#   inflating: dataset_yolo2/images/val/healthy/fd92bd9c-02cb-4599-8673-9316159504a1___RS_HL 1927.JPG
#   inflating: dataset_yolo2/images/val/healthy/fdbbea63-18e0-401f-8269-64ba005ab53f___RS_HL 0213.JPG
#   inflating: dataset_yolo2/images/val/healthy/fde29807-8223-4fc5-a06b-7cc93101a6d1___GH_HL Leaf 174.JPG
#   inflating: dataset_yolo2/images/val/healthy/fe682576-9a9b-40c9-a875-62af05d3bc1e___JR_HL 7984.JPG
#   inflating: dataset_yolo2/images/val/healthy/fe8f8808-2631-491e-a46b-bd2a1a4958e7___GH_HL Leaf 213.1.JPG
#   inflating: dataset_yolo2/images/val/healthy/fe978613-05fc-4b11-a2d0-2175915f74c1___JR_HL 8105.JPG
#   inflating: dataset_yolo2/images/val/healthy/ff55573a-3ae9-4c76-957b-6b3e2665f4a3___JR_HL 8701.JPG
#   inflating: dataset_yolo2/images/val/healthy/ff8b36d5-feaf-4d2d-8126-18670a312657___RS_HL 0229.JPG
#    creating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/0022d6b7-d47c-4ee2-ae9a-392a53f48647___JR_B.Spot 8964.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/01613cd0-d3cd-4e96-945c-a312002037bf___JR_B.Spot 3262.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/01dfb88b-cd5a-420c-b163-51f5fe07b74d___JR_B.Spot 9091.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/032aa7c4-0a95-4f09-b0bb-1242f4f32d82___NREC_B.Spot 1889.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/0576dd21-3958-46a5-ab99-f9865371bd1a___NREC_B.Spot 1957.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/05c6ea65-cce4-43da-b57b-a45321b0e51b___NREC_B.Spot 9048.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/0d8421cd-eebc-4018-b591-12352dd970a7___JR_B.Spot 3234.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/1044c742-39a0-4b1a-984f-3cb2bdeda94b___NREC_B.Spot 9219.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/1092e87d-5d66-43cd-8344-43b393d86065___NREC_B.Spot 9244.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/11a23270-53e7-41b6-8c79-91caeaf9cfa6___JR_B.Spot 9050.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/1219f26f-a23a-4c2a-99f0-407fc785c74a___JR_B.Spot 3332.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/12342367-f62b-40d0-897b-77bd1edbd3d1___JR_B.Spot 3199.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/12c9c98f-afc9-4c12-8a97-007e5a40712a___NREC_B.Spot 9053.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/162a3375-31e6-48f4-9b78-ab35054fb86c___JR_B.Spot 3397.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/1732db7e-9901-46df-b20e-3ca49ff1dbad___NREC_B.Spot 1791.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/17737361-6967-452a-ac5d-efebaa1d8a35___NREC_B.Spot 9127.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/1a1af0c4-9e4a-4158-b982-f81d487a3b68___NREC_B.Spot 9148.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/1b589f92-a658-4e58-96de-db41acc411ce___JR_B.Spot 3239.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/1cce64aa-6f9f-4ce1-b319-dbc4a012b240___JR_B.Spot 8998.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/1d89d58f-09d2-42ee-a9dc-11e51d0a1635___JR_B.Spot 8826.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/1fca0f2b-857b-4cef-9218-42b1bdd92d00___JR_B.Spot 8969.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/20a9aed4-ba56-413d-b88d-f4491cf184b3___JR_B.Spot 3265.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/2254cc78-9169-4f14-9ab9-d9d3949a5f69___JR_B.Spot 3295.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/2414f9df-91fd-4aed-b772-bd6b5311eb0b___JR_B.Spot 3141.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/284b0fae-ce3c-43e7-acc6-e9a22bd6eb6f___JR_B.Spot 9074.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/28f23e77-e556-40c8-8bc2-835227732de2___JR_B.Spot 8848.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/2adcf097-e515-49f1-9716-c0d06d8b52b4___NREC_B.Spot 1933.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/2bb75692-d488-406d-bce0-c7eab42557c5___NREC_B.Spot 1922.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/2edf5fe8-706b-4ce7-8b59-dc6bfa4b6b42___JR_B.Spot 8823.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/315668fd-452d-43c1-8a63-e3b4d3d634a7___JR_B.Spot 3097.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/33952a4a-ef41-4eff-9a2a-35bbea1b6686___JR_B.Spot 3200.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/36aa1467-175d-42d0-8da3-99e8ffd06fbe___NREC_B.Spot 1905.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/39875cb8-3958-46b9-a9dc-f810f353af5a___JR_B.Spot 3321.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/3a56f122-0d06-45c2-bc2b-0636d42a7545___JR_B.Spot 9088.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/3c237d3f-7242-4009-a08a-b4eb7cd662fc___NREC_B.Spot 1969.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/3d0ebe4c-591f-490f-b389-cd8f424acbba___JR_B.Spot 9041.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/3d203d3a-3614-4ddf-9956-0c6a12208c7e___JR_B.Spot 3391.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/3d6a3d51-8a9f-42ff-b4bf-299778c3e0a8___JR_B.Spot 3184.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/3df25df9-50f7-4430-8853-0ab2d3ca2579___JR_B.Spot 9083.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/3f436076-8f23-46e8-a730-08bffac34ea4___JR_B.Spot 3379.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/447735c7-b650-4ef6-a53b-8fb661470de3___JR_B.Spot 3370.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/490afec2-acdf-4b61-b137-43d43285817c___JR_B.Spot 8949.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/4bad40b0-af40-4deb-820c-edbcbb9ea372___NREC_B.Spot 1843.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/4c34e3ed-523a-414d-b28d-52078277cb67___NREC_B.Spot 9174.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/4f49f8c2-d091-40d0-b85c-db10099b3caa___NREC_B.Spot 9171.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/51185964-48e2-493e-a052-42139dd0facd___JR_B.Spot 3331.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/525555a6-c09c-4551-8b9d-d2a8050f474d___JR_B.Spot 3355.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/5640520e-087c-41ae-b462-c30d8aa51aab___JR_B.Spot 8914.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/58e3b37c-5192-4a03-9f8a-da00330c529a___NREC_B.Spot 9237.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/5d17a185-67fe-465f-81b9-35d936f24f99___JR_B.Spot 3181.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/5f7e373c-1bcb-4730-b55d-d0caf375bb0b___JR_B.Spot 8948.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/61764b09-9bb9-44b3-af94-d3408045b7c3___NREC_B.Spot 1891.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/64ed4b17-84ad-4088-b079-c02eceef5e7e___NREC_B.Spot 1958.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/65de6d37-4ea5-4ac7-af08-a974eb5b501a___NREC_B.Spot 9106.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/6b1b260e-fab5-4a73-936c-5592119c13fe___NREC_B.Spot 1952.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/6c859178-38ef-450e-8e93-c357957f5608___NREC_B.Spot 9061.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/6cf6e676-20a1-45bc-8f5f-48445e5cbaa8___NREC_B.Spot 9086.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/6e1e07ba-212d-4494-b8bf-73d12d720c20___JR_B.Spot 3392.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/6e789f9f-96b0-4221-9755-a75ca579def7___NREC_B.Spot 1795.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/731d3112-8dfa-4ce0-b27e-6a0cdb661a6d___NREC_B.Spot 9232.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/78cbd7cf-98fb-41f1-ae32-6655c02fa49c___JR_B.Spot 3292.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/796c804e-6764-4497-8ded-dc7ac3f0112c___JR_B.Spot 9007.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/799cf6ba-63c7-442c-b33a-4b1d31b00eac___NREC_B.Spot 1852.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/7b3f4992-f771-4b6e-b25f-7ec4c5823c88___JR_B.Spot 8951.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/7b7b589f-1bb8-43fb-8fa0-b510e200dd99___JR_B.Spot 9061.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/7c719504-0327-4be0-b898-b50760a26de6___JR_B.Spot 3310.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/7f07dc8d-dc42-4b4a-89a8-f2d2e10bdba7___NREC_B.Spot 9167.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/816dee9f-b43f-42da-b0c9-3fb8b29d511d___NREC_B.Spot 9182.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/820a7257-dc1d-46af-ba5a-b006c35fc1b1___JR_B.Spot 3116.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/82b9fdcc-3000-46fe-b955-063e77dd5968___JR_B.Spot 3324.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/836b4b9e-85d5-47bc-ad93-9ab31b07be3d___JR_B.Spot 3361.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/8631f961-c7d1-4ce8-b777-44aa9fbdb24a___JR_B.Spot 3180.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/8695a15f-cdb4-444f-817b-7f4fc22a7a7a___NREC_B.Spot 9230.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/875f41e8-cd70-44f4-a17c-c8b77fed406c___JR_B.Spot 8902.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/884c2da1-3b43-46aa-85bb-0f72ed25c266___JR_B.Spot 8906.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/8a9bc15a-fd14-44ac-b8eb-37ea8a209406___NREC_B.Spot 1819.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/8e049c5d-6a3b-4972-94e3-057e6cbe3892___NREC_B.Spot 1901.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/8efc7a6c-216f-4c32-99a1-43335c3385a8___JR_B.Spot 3213.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/8f9dedbd-e4c2-4bbb-b9c4-efb8d61bddc2___NREC_B.Spot 1882.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/952535f2-d337-434c-90e4-0be62ad20db9___JR_B.Spot 3348.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/969f1458-b7a9-4880-9759-05b0005c978e___JR_B.Spot 8978.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/97fa8b63-1a92-4760-802c-2acfecc67e65___JR_B.Spot 8827.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/98558acc-09f4-4d2f-bdff-5e8e915ea606___NREC_B.Spot 9141.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/994dd8b0-a87e-485a-be38-cb01b8843e44___JR_B.Spot 8857.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/9be6504b-0be3-4169-80dd-139f579504a3___JR_B.Spot 8963.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/9c23ddea-18e9-4b79-b890-77c6077d8966___JR_B.Spot 3195.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/9e501de6-b39a-4a9c-b5f7-f55a246c02b6___NREC_B.Spot 9207.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/a32c2976-7ef3-4dfa-95d8-c3c056b36012___JR_B.Spot 3145.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/a3407dfc-9a97-4dd4-b484-527da44a161c___JR_B.Spot 9029.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/a3f4ee94-8c9f-4c38-8e64-b3928e6b3a95___JR_B.Spot 3204.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/a664ab66-84d0-4bcf-b771-46db16372dda___NREC_B.Spot 1970.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/ab5f2fed-0c46-46ad-b63a-86760db73e6a___JR_B.Spot 3354.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/abc52078-90cf-426a-8ed8-602a35243d3e___NREC_B.Spot 9221.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/af2e0582-8683-4b26-a3e2-0e17b2de09c6___NREC_B.Spot 1848.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/afc76c77-fd2d-4b7f-b1ad-14ba4d5fe297___NREC_B.Spot 9113.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/b1c60a36-0aa1-4051-8dfe-db3ab7feeb39___JR_B.Spot 3406.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/b22693c9-a87d-4ffa-82b1-0218e1b966be___JR_B.Spot 3277.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/b36819f5-6791-44da-96ac-b89069921af6___JR_B.Spot 3130.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/b810580c-a559-4c50-8378-0ec894de8a36___NREC_B.Spot 1838.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/b82e0746-97b5-4be9-90a7-ac2b2121428c___JR_B.Spot 9073.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/b8eff1e7-9059-4c11-b931-fc1bc4ee0ae1___NREC_B.Spot 1972.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/b928cffb-f480-44a8-9b09-70ef158fdc7c___JR_B.Spot 3155.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/ba9e7d81-876f-4c05-9578-ddd45d8b3526___JR_B.Spot 3330.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/baaf70ae-a980-4cf0-a012-de1c2a35a2bd___JR_B.Spot 8822.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/bac5f227-64b0-4064-9716-611dd35c2897___JR_B.Spot 3103.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/bcf56f7d-d584-4fed-b42e-5cbf3b8707b7___JR_B.Spot 3197.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/bd2fcca9-6e34-44db-ade7-a0b595c97dcf___NREC_B.Spot 9126.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/bd493982-5fe3-4851-b4d3-1e9e962f1d70___NREC_B.Spot 1876.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/c21c9506-e89f-4ff4-b9f1-7a666de39f50___NREC_B.Spot 9078.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/c4791388-b93b-4cad-9ee8-e243c2847f0c___JR_B.Spot 9024.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/c5ae280d-bbc4-4ef5-8c09-38a241b8c00d___NREC_B.Spot 9199.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/c8080916-dd9d-40c4-a39b-1957ebd17b87___NREC_B.Spot 9115.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/c8ea8547-4f93-4bf9-af69-79f09697e817___JR_B.Spot 3152.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/c94ae9a2-f5b0-4da4-9bd1-c66ef5b0ad74___JR_B.Spot 3167.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/ca536e69-ebc0-4a82-8bca-c074f9399885___JR_B.Spot 8986.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/caa7bde5-3d2d-484c-8c71-607b4b1041f8___JR_B.Spot 8870.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/cd35e968-1e90-4fc9-a0d1-574b89bc3019___NREC_B.Spot 9082.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/cec0354e-5caf-4eb7-9fa5-a7b07ac1b644___JR_B.Spot 9070.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/d2b4564a-7428-4f27-ae26-d30c9d013cd8___JR_B.Spot 8917.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/d3522fcb-a325-48b2-8b37-881a56e190e4___NREC_B.Spot 9047.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/d6b7a95f-019c-4cf6-b7da-d8bdc18a6c76___JR_B.Spot 9028.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/d6ec81e9-4a00-4b62-9e45-0d4fde6a5c68___NREC_B.Spot 1850.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/d890ffc6-e6c8-4ef6-bde4-980cf0a465e1___JR_B.Spot 8945.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/d9d20fce-3cef-4c89-8a3f-7294e05df853___JR_B.Spot 3225.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/da982561-a660-482e-bccc-72bdff79e454___NREC_B.Spot 1966.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/dab1cfaf-544d-48e0-bfe7-368d65761902___JR_B.Spot 8904.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/db2c9432-9f29-4867-a07f-b6e78aa946a4___JR_B.Spot 3138.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/db56c75b-22ed-473b-91ce-814d78d38574___JR_B.Spot 3325.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/debfee6b-a167-480c-88dc-2b02279d7e93___JR_B.Spot 3158.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/e26d8f48-59aa-4261-ba5a-a4461ebba8d2___JR_B.Spot 3222.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/e348be18-797b-48ab-856a-3e58bde6c874___JR_B.Spot 3229.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/e5a83007-3ed6-4621-ac3f-75337614f490___NREC_B.Spot 9209.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/e71b39c4-8007-46c0-a925-adaf30e71fd1___JR_B.Spot 9054.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/e96d2d14-4400-4c28-894e-be7c071743f4___NREC_B.Spot 9175.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/eabaa1bb-a866-4670-887e-3d9897c31fae___JR_B.Spot 3274.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/ead27319-4073-490e-80a0-08e916bbc1f2___JR_B.Spot 9084.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/eb2fd423-38f8-42b5-88bf-4fdc81adba95___JR_B.Spot 8952.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/ebe12503-1abc-4e09-9eee-3180b67c29f4___JR_B.Spot 8849.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/ee7addf1-7941-463f-899e-3c38cafea9df___JR_B.Spot 9002.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/ef82ea58-8cfe-4e8f-a935-2b4e143618b1___JR_B.Spot 9079.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/f0f2b399-c9fe-462a-961c-2cfc9e5318b9___NREC_B.Spot 9101.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/f176a365-b5f0-4b3f-a4bc-d4d2c705b29e___JR_B.Spot 3263.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/f2c48f6c-f92e-4543-816c-0621648003fe___JR_B.Spot 9010.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/f2e21841-962e-4044-bb5d-efd8af95df74___NREC_B.Spot 1893.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/f47251cd-5d05-4d98-847c-4e1ae180333a___NREC_B.Spot 1965.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/f6a20939-1617-49f7-a7a4-1dde2020426b___JR_B.Spot 3365.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/f73b390b-591a-4f25-991d-3ff77a92a6f5___JR_B.Spot 3357.JPG
#   inflating: dataset_yolo2/images/val/Pepper__bell___Bacterial_spot/ff81e22a-09bf-49bd-b45a-c75606cd113b___NREC_B.Spot 1811.JPG
# ...
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/c96e4abf-404d-40ab-b105-827dde90c4a7___Com.G_SpM_FL 9331.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/c992dcf1-a2de-4de7-b403-bb357efc80ab___Com.G_SpM_FL 1645.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/ca35c94a-8397-46bc-96ee-7ec634cd8ea6___Com.G_SpM_FL 1173.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/cb50c515-6885-4fc5-903e-b9fbac229a37___Com.G_SpM_FL 1667.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/cc736449-0d02-4b8b-b8c1-d6bbcd7b863f___Com.G_SpM_FL 8954.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/cd69a28b-61e1-476c-8a44-9c584cde6c2a___Com.G_SpM_FL 9481.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/cdf3b1b8-c0dd-45dc-98dd-3a95be77e0a3___Com.G_SpM_FL 9538.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/cf3bd731-bbcd-494e-86a2-793f1e944bb5___Com.G_SpM_FL 9462.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/cfec2513-cdcc-4780-9d3f-2e794c421915___Com.G_SpM_FL 1317.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d05b2e21-1ba0-473a-889b-2a438dadac39___Com.G_SpM_FL 8750.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d0cd0d30-a825-4ddb-9df6-c767b101735c___Com.G_SpM_FL 1630.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d2184d36-c149-4bab-bc07-66c9afce4567___Com.G_SpM_FL 9507.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d222c176-f267-4c87-ba98-81ebc37f53b1___Com.G_SpM_FL 8675.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d227dad9-205e-4dc9-8949-bc40113d4f21___Com.G_SpM_FL 8805.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d2414051-ad35-4413-8305-9285c5acdc79___Com.G_SpM_FL 9524.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d2785da0-30ff-49d1-bf7d-9a2f07412b64___Com.G_SpM_FL 1149.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d3732d4c-b7a5-4a11-9290-d3faf28c204b___Com.G_SpM_FL 9023.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d40c6c6f-396b-4032-ac0c-92d49b6ecea9___Com.G_SpM_FL 9457.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d4662c2b-94a2-4957-be81-b3a7d2f74032___Com.G_SpM_FL 8484.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d46c0f86-ec4b-45bb-aa0a-36a109246011___Com.G_SpM_FL 8957.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d56e9013-62c8-4678-95ae-6b9f7e2e16bf___Com.G_SpM_FL 9627.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d58dce86-2332-4c60-92c7-d033ddb9d0ef___Com.G_SpM_FL 1709.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d5d0d5ae-7bcf-407b-ab78-84950dc1980c___Com.G_SpM_FL 8703.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d64bb364-65c3-401d-b9b9-56fad8fbfdd8___Com.G_SpM_FL 8804.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d652a294-f4fe-4a9d-afb4-3aa011fe5522___Com.G_SpM_FL 8666.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d6742063-9b9e-42b7-9ac4-bda7e2eeb12d___Com.G_SpM_FL 8813.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d697c77a-7cd1-4790-8ec4-437513fad107___Com.G_SpM_FL 1215.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d82a6309-65c7-48f8-b661-4a944f7930cd___Com.G_SpM_FL 1778.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d90a9ec7-89f8-4c31-855e-368a5b66be3d___Com.G_SpM_FL 1626.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/d9d22025-cee6-4963-ac70-bfa8a7af30a2___Com.G_SpM_FL 1624.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/da35732b-f238-4099-bac4-f8bd5aaa9650___Com.G_SpM_FL 8998.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/daa3aaa8-41a1-4b46-9b3e-3363ac2fb737___Com.G_SpM_FL 1210.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/dba37938-bb5c-41cd-9a81-76827e1e2bbd___Com.G_SpM_FL 9466.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/dbc0310f-d3e8-44d2-9565-c77cdf1bda7d___Com.G_SpM_FL 8626.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/dbdc03e7-aed5-415b-9b93-2e47ef27f1c3___Com.G_SpM_FL 8498.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/dd65aea5-06e3-4e06-b3e0-3466c629c389___Com.G_SpM_FL 9001.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/ddee4e2d-6500-4bb7-baa8-e938dae78751___Com.G_SpM_FL 1504.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/decfa616-56e5-472d-b1a3-cc9681f3676c___Com.G_SpM_FL 8659.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/df5b37b7-f3aa-4659-85c7-fef204ad110e___Com.G_SpM_FL 1585.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/df84f40f-a2b6-49db-af29-cb8917674a93___Com.G_SpM_FL 8588.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/dfb1508d-3c5b-420a-ac9c-919602530ef2___Com.G_SpM_FL 8695.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e1170356-0933-423b-a247-fa0da8b52cea___Com.G_SpM_FL 1239.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e13060fe-90fb-49c9-ab46-9a4cfd68c02a___Com.G_SpM_FL 1749.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e183beb7-febd-448b-83eb-2d92b88a8def___Com.G_SpM_FL 1531.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e1b32a63-c580-47e4-a2e9-d08d32923d9d___Com.G_SpM_FL 8420.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e1c88203-3d8b-410f-9d4b-d35c7a735ddf___Com.G_SpM_FL 1267.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e1cb3386-f090-4170-b8c1-d602d49583f8___Com.G_SpM_FL 1399.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e2aa2f14-9b4e-4b25-aa44-797be70717f4___Com.G_SpM_FL 1620.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e3540464-df30-4477-8bf6-66501f270508___Com.G_SpM_FL 8501.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e3ea3bcf-d037-44df-a877-d8df8d7b5dc4___Com.G_SpM_FL 1759.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e4136455-c279-44f4-9996-c553e4f11245___Com.G_SpM_FL 8557.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e421fcb0-be23-4ff8-a5f0-0ee7110160e5___Com.G_SpM_FL 1680.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e6cfc638-fdee-4471-a0ce-994a33447558___Com.G_SpM_FL 1617.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e6ebca7a-cacc-4ca4-bf8b-1c5f63f847dc___Com.G_SpM_FL 1511.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e7b889f3-d580-426e-83fb-6519f43935ef___Com.G_SpM_FL 8690.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e888eec7-f355-4611-a28f-137f034474e5___Com.G_SpM_FL 8847.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e8eacb74-00fe-4e44-beec-f29c4bb58c58___Com.G_SpM_FL 8479.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e90ba377-d69d-47ef-808c-c6ba488da79f___Com.G_SpM_FL 8958.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/e9b2e448-c8b7-4fde-b1f2-1ab86dce0b86___Com.G_SpM_FL 1330.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/ea1958cc-ff91-4651-966b-e85e4c7c7abe___Com.G_SpM_FL 8488.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/ea4ee443-4595-404c-818a-9a52e43577db___Com.G_SpM_FL 8503.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/ea697bbb-9f03-4415-980e-9966f66f1e8c___Com.G_SpM_FL 8678.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/eaa10d61-de43-4eb3-9008-07d2d436005d___Com.G_SpM_FL 9003.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/eac6b680-4e8b-48bf-b85b-c2296d7c1853___Com.G_SpM_FL 9565.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/eaf27f54-d679-4fec-831a-41d1d18b286d___Com.G_SpM_FL 8455.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/ec9d26e5-50f0-4684-a90e-4a5eae635e6b___Com.G_SpM_FL 9032.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/ed4959f6-0ad7-4e9e-a1df-09d1160780d1___Com.G_SpM_FL 8797.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/edd1f4cc-f94d-4e4a-af9d-56a93a6068c4___Com.G_SpM_FL 8507.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/edd90a56-3a0f-4b3c-a55e-0e0a73bdf18d___Com.G_SpM_FL 1689.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/edfb0fe5-a10c-469d-9346-802e68dfcd58___Com.G_SpM_FL 9390.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/ef3fd109-228e-4e7b-8b22-277e41a79335___Com.G_SpM_FL 9542.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/efd35611-5d21-4479-b279-00cfa75e8042___Com.G_SpM_FL 8429.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/efe61ff3-0b11-412e-ab4e-5d27f7d1cfaa___Com.G_SpM_FL 9613.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f03ba5ea-8380-4386-9e30-2e588a27d94a___Com.G_SpM_FL 9526.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f03d3d30-cc06-48e0-9a8f-978f705cc2e8___Com.G_SpM_FL 1278.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f18824ce-b2f5-4320-8984-340fdc1416c9___Com.G_SpM_FL 9591.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f2eb1f1a-3973-4ebf-8392-19d12f0ab759___Com.G_SpM_FL 8740.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f34c4c14-fa28-4761-aeb3-7d00fa139bef___Com.G_SpM_FL 8481.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f41b78aa-281c-416f-9d9b-4a5a3d9f20fc___Com.G_SpM_FL 9012.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f47ddff5-50f1-4eb0-b8bf-6980fe776162___Com.G_SpM_FL 1695.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f4e7971e-2b38-49c8-9cd8-7d0a5431ac40___Com.G_SpM_FL 1567.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f4f765b8-958b-4266-981e-2320454ac4ab___Com.G_SpM_FL 9356.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f58ec82b-b2ac-4120-b612-bb48a2f68e15___Com.G_SpM_FL 8959.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f598ab69-e947-4664-9df0-0ba133e40b30___Com.G_SpM_FL 9504.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f5cf6938-855e-479f-b909-a9bc12fcb76c___Com.G_SpM_FL 8733.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f600d9c2-090a-4711-a3ac-8d48a709173d___Com.G_SpM_FL 1774.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f6d125d8-795a-40ac-91d7-142f6cf023eb___Com.G_SpM_FL 9262.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f718db12-7a16-437d-905c-f804e21383c8___Com.G_SpM_FL 1353.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f7494345-4bb3-42b8-8043-689059c28424___Com.G_SpM_FL 8688.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f7676e6d-a9f2-4c4e-b15c-305f9f16aaa1___Com.G_SpM_FL 9415.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f7b7b4c8-1420-4ffe-ba64-97be026edeb4___Com.G_SpM_FL 8978.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f822bd69-f201-488c-8f25-e3c4449ec308___Com.G_SpM_FL 8665.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f83250d9-6b08-4a6c-b135-8d80cc4f258e___Com.G_SpM_FL 1170.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f8b06c4f-6f3a-44dd-9a70-2ab2a9be23e6___Com.G_SpM_FL 1534.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/f9493a24-68a7-4c75-b943-0fe5b69405df___Com.G_SpM_FL 8648.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fa497010-52f0-46df-90ab-c40e1d9bb34b___Com.G_SpM_FL 8542.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fb4d0983-9df9-40be-8b1c-bbd5b9aa3620___Com.G_SpM_FL 1770.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fb5551c8-d45c-4c92-8cd2-c389d4268c54___Com.G_SpM_FL 8827.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fb7d1c6e-6d3c-4f03-b8dd-9c51740ed23a___Com.G_SpM_FL 1681.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fbabfa17-0b7e-4c83-bb10-ebcf80515ce7___Com.G_SpM_FL 8741.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fc6bc29e-ac80-4326-b8aa-94dbcdd1f086___Com.G_SpM_FL 8610.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fd2cc1ea-22d9-4c3f-80c6-0c9dc40bdcaa___Com.G_SpM_FL 9006.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fd4f7201-2f81-4650-8681-dd56406417af___Com.G_SpM_FL 1364.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fd665d64-3079-45da-b719-0e45b9a65a84___Com.G_SpM_FL 1255.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fd71ebe5-4ce6-4b19-b71e-cb66b034c123___Com.G_SpM_FL 1282.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fddf2531-e2d5-4e98-8b8d-725088227b66___Com.G_SpM_FL 1565.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fe71b883-7106-4a92-85b6-09e6015ff0ff___Com.G_SpM_FL 9303.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/fe791e06-a48b-4967-99e9-083d18d0d91c___Com.G_SpM_FL 8761.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/ff146f2c-dbb7-4da0-aa98-a36351435489___Com.G_SpM_FL 9654.JPG
#   inflating: dataset_yolo2/images/val/Tomato_Spider_mites_Two_spotted_spider_mite/ffb00771-1462-4c9d-962b-7aaa7e8d5a51___Com.G_SpM_FL 1411.JPG

# %%
train_dataset = LeafDataset(train_data, train=True)
val_dataset   = LeafDataset(val_data, train=False)
test_dataset  = LeafDataset(test_data, train=False)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
class_num=len(classes)
model = models.resnet50(weights="DEFAULT", progress=True)
model.fc = nn.Linear(model.fc.in_features, class_num)





model=model.to(device)
loss_fun=nn.CrossEntropyLoss(weight=class_weights)
optimizer=torch.optim.Adam(model.fc.parameters(),lr=3e-4)
epochs=20
patience = 5
best_val_loss = float("inf")
counter = 0
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 196MB/s]

# %%
# ---------- Freeze backbone ----------
for param in model.parameters():
    param.requires_grad = False

for param in model.fc.parameters():
    param.requires_grad = True
freeze_epochs = 3
for epoch in range(epochs):
    if epoch == freeze_epochs:
        print("Unfreezing backbone...")

        for param in model.parameters():
            param.requires_grad = True
        optimizer=torch.optim.Adam(model.parameters(),lr=1e-4)

    model.train()

    running_loss = 0
    correct = 0
    total = 0

    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}")

    for images, labels in loop:

        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)

        loss = loss_fun(outputs, labels)

        loss.backward()

        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        loop.set_postfix(
            loss=running_loss/len(train_loader),
            acc=100*correct/total
        )

    model.eval()

    val_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in val_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            loss = loss_fun(outputs, labels)

            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_loss = val_loss / len(val_loader)
    val_acc = 100 * correct / total

    print(f"\nValidation Loss: {val_loss:.4f}")
    print(f"Validation Accuracy: {val_acc:.2f}%")

    if val_loss < best_val_loss:

        best_val_loss = val_loss
        counter = 0

        torch.save(model.state_dict(), "best_model_resnet.pth")

        print("Validation improved, model saved!")

    else:

        counter += 1
        print(f"No improvement for {counter} epochs")

        if counter >= patience:
            print("Early stopping triggered!")
            break
# Out:
# Epoch 1/20: 100%|██████████| 855/855 [02:24<00:00,  5.93it/s, acc=62.1, loss=1.6]
# Validation Loss: 1.1728
# Validation Accuracy: 69.20%
# Validation improved, model saved!
# Epoch 2/20: 100%|██████████| 855/855 [01:59<00:00,  7.15it/s, acc=74.2, loss=1.01]
# Validation Loss: 0.9027
# Validation Accuracy: 75.21%
# Validation improved, model saved!
# Epoch 3/20: 100%|██████████| 855/855 [01:59<00:00,  7.14it/s, acc=77.5, loss=0.839]
# Validation Loss: 0.7600
# Validation Accuracy: 77.92%
# Validation improved, model saved!
# Unfreezing backbone...
# Epoch 4/20: 100%|██████████| 855/855 [03:38<00:00,  3.92it/s, acc=91.2, loss=0.277]
# Validation Loss: 0.0713
# Validation Accuracy: 97.48%
# Validation improved, model saved!
# Epoch 5/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=95.2, loss=0.144]
# Validation Loss: 0.0376
# Validation Accuracy: 98.87%
# Validation improved, model saved!
# Epoch 6/20: 100%|██████████| 855/855 [03:38<00:00,  3.92it/s, acc=96.3, loss=0.111]
# Validation Loss: 0.0350
# Validation Accuracy: 98.80%
# Validation improved, model saved!
# Epoch 7/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=97, loss=0.0947]
# Validation Loss: 0.0258
# Validation Accuracy: 99.05%
# Validation improved, model saved!
# Epoch 8/20: 100%|██████████| 855/855 [03:38<00:00,  3.92it/s, acc=97.1, loss=0.0854]
# Validation Loss: 0.0186
# Validation Accuracy: 99.36%
# Validation improved, model saved!
# Epoch 9/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=97.5, loss=0.0771]
# Validation Loss: 0.0118
# Validation Accuracy: 99.61%
# Validation improved, model saved!
# Epoch 10/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=97.5, loss=0.0755]
# Validation Loss: 0.0100
# Validation Accuracy: 99.79%
# Validation improved, model saved!
# Epoch 11/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=97.9, loss=0.0655]
# Validation Loss: 0.0079
# Validation Accuracy: 99.82%
# Validation improved, model saved!
# Epoch 12/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=97.9, loss=0.0674]
# Validation Loss: 0.0107
# Validation Accuracy: 99.71%
# No improvement for 1 epochs
# Epoch 13/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=97.8, loss=0.0667]
# Validation Loss: 0.0138
# Validation Accuracy: 99.52%
# No improvement for 2 epochs
# Epoch 14/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=98, loss=0.0604]
# Validation Loss: 0.0160
# Validation Accuracy: 99.59%
# No improvement for 3 epochs
# Epoch 15/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=98.3, loss=0.0511]
# Validation Loss: 0.0058
# Validation Accuracy: 99.89%
# Validation improved, model saved!
# Epoch 16/20: 100%|██████████| 855/855 [03:39<00:00,  3.90it/s, acc=98.2, loss=0.0555]
# Validation Loss: 0.0089
# Validation Accuracy: 99.71%
# No improvement for 1 epochs
# Epoch 17/20: 100%|██████████| 855/855 [03:39<00:00,  3.90it/s, acc=98.3, loss=0.0545]
# Validation Loss: 0.0057
# Validation Accuracy: 99.91%
# Validation improved, model saved!
# Epoch 18/20: 100%|██████████| 855/855 [03:39<00:00,  3.90it/s, acc=98.4, loss=0.0488]
# Validation Loss: 0.0033
# Validation Accuracy: 99.95%
# Validation improved, model saved!
# Epoch 19/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=98.3, loss=0.0515]
# Validation Loss: 0.0121
# Validation Accuracy: 99.55%
# No improvement for 1 epochs
# Epoch 20/20: 100%|██████████| 855/855 [03:38<00:00,  3.91it/s, acc=98.4, loss=0.0504]
# Validation Loss: 0.0092
# Validation Accuracy: 99.75%
# No improvement for 2 epochs

# %%
model.load_state_dict(torch.load("best_model_resnet.pth",map_location=device,weights_only=True))
# Out:
# <All keys matched successfully>

# %%
from sklearn.metrics import classification_report
model.eval()

test_loss = 0
correct = 0
total = 0

all_preds = []
all_labels = []

with torch.no_grad():

    loop = tqdm(test_loader, desc="Testing")

    for images, labels in loop:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        loss = loss_fun(outputs, labels)

        test_loss += loss.item()

        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_loss /= len(test_loader)
test_acc = 100 * correct / total

print("\nTest Results")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2f}%")

print("\nClassification Report:")
print(classification_report(all_labels, all_preds, target_names=classes))
# Out:
# Testing: 100%|██████████| 176/176 [00:45<00:00,  3.89it/s]
# Test Results
# Test Loss: 0.0119
# Test Accuracy: 99.72%
#
# Classification Report:
#                                              precision    recall  f1-score   support
#
#               Pepper__bell___Bacterial_spot       0.99      0.99      0.99       151
#                       Potato___Early_blight       1.00      1.00      1.00       274
#                        Potato___Late_blight       1.00      1.00      1.00       283
#                       Tomato_Bacterial_spot       1.00      0.99      1.00       581
#                         Tomato_Early_blight       0.99      1.00      0.99       284
#                          Tomato_Late_blight       0.99      0.99      0.99       531
#                            Tomato_Leaf_Mold       1.00      1.00      1.00       272
#                   Tomato_Septoria_leaf_spot       1.00      1.00      1.00       495
# Tomato_Spider_mites_Two_spotted_spider_mite       1.00      1.00      1.00       464
#                         Tomato__Target_Spot       1.00      0.99      1.00       392
#       Tomato__Tomato_YellowLeaf__Curl_Virus       1.00      1.00      1.00       893
#                 Tomato__Tomato_mosaic_virus       1.00      1.00      1.00       103
#                                     healthy       1.00      1.00      1.00       893
#
#                                    accuracy                           1.00      5616
#                                   macro avg       1.00      1.00      1.00      5616
#                                weighted avg       1.00      1.00      1.00      5616

# %%
# target_layers = [model.layer3[-1]]
# gradcam_dirs = [
#     "Datasets/dataset_yolo2/images/train",
#     "Datasets/dataset_yolo2/images/val"
# ]
# output_dir = "gradcam_results"
# os.makedirs(output_dir, exist_ok=True)
# cam = GradCAMPlusPlus(model=model, target_layers=target_layers)
#
# labels_dir = "yolo_labels"
# os.makedirs(labels_dir, exist_ok=True)

# %%
INPUT_BASE = "dataset_yolo2"
OUTPUT_BASE = "dataset_yolo2_generated"

gradcam_dirs = [
    os.path.join(INPUT_BASE, "images/train"),
    os.path.join(INPUT_BASE, "images/val")
]

unet_mask_dir = "unet_masks"
output_dir = "gradcam_results"

os.makedirs(unet_mask_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

# ==============================
# MODEL + CAM
# ==============================

cam = ScoreCAM(
    model=model,
    target_layers=target_layers,
    use_cuda=torch.cuda.is_available()
)


# ==============================
# MAIN LOOP
# ==============================

counter = 0

for dataset_dir in gradcam_dirs:
    split = os.path.basename(dataset_dir)

    yolo_labels_dir = os.path.join(OUTPUT_BASE, "labels", split)
    yolo_images_dir = os.path.join(OUTPUT_BASE, "images", split)

    os.makedirs(yolo_labels_dir, exist_ok=True)
    os.makedirs(yolo_images_dir, exist_ok=True)

    for class_name in os.listdir(dataset_dir):

        class_folder = os.path.join(dataset_dir, class_name)

        if not os.path.isdir(class_folder):
            continue

        for img_name in tqdm(os.listdir(class_folder), desc=f"{split} - {class_name}"):

            if not img_name.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp')):
                continue

            counter += 1

            img_path = os.path.join(class_folder, img_name)
            base_name = os.path.splitext(img_name)[0]

            yolo_img_path = os.path.join(yolo_images_dir, img_name)
            label_path = os.path.join(yolo_labels_dir, f"{base_name}.txt")

            # 🔥 NEW: class name at beginning
            save_path = os.path.join(output_dir, f"{class_name}_{split}_{base_name}.jpg")

            try:
                # ==============================
                # LOAD IMAGE
                # ==============================
                image = Image.open(img_path).convert("RGB")
                original_img = cv2.resize(np.array(image), (224, 224))

                # ==============================
                # LEAF SEGMENTATION
                # ==============================
                leaf, leaf_mask = extract_leaf_mask(original_img)
                if leaf is None:
                    continue

                rgb_img = original_img.astype(np.float32) / 255.0

                image_tensor = preprocess_image(
                    Image.fromarray(original_img),
                    train=False
                ).unsqueeze(0).to(device)

                # ==============================
                # PREDICTION
                # ==============================
                outputs = model(image_tensor)
                class_id = outputs.argmax(dim=1).item()
                targets = [ClassifierOutputTarget(class_id)]

                is_healthy = "healthy" in class_name.lower()

                # ==============================
                # SAVE IMAGE
                # ==============================
                if not os.path.exists(yolo_img_path):
                    cv2.imwrite(yolo_img_path, cv2.cvtColor(original_img, cv2.COLOR_RGB2BGR))

                # ==============================
                # MASK GENERATION
                # ==============================
                if is_healthy:
                    mask = leaf_mask
                    visualization = rgb_img

                else:
                    grayscale_cam = cam(input_tensor=image_tensor, targets=targets)

                    if grayscale_cam is None:
                        continue

                    if len(grayscale_cam.shape) == 3:
                        grayscale_cam = grayscale_cam[0]

                    # Restrict to leaf
                    leaf_mask_float = leaf_mask.astype(np.float32) / 255.0
                    grayscale_cam *= leaf_mask_float

                    cam_min, cam_max = grayscale_cam.min(), grayscale_cam.max()
                    if cam_max - cam_min == 0:
                        continue

                    heatmap_norm = (grayscale_cam - cam_min) / (cam_max - cam_min)

                    threshold = np.percentile(heatmap_norm, 90)
                    mask = (heatmap_norm >= threshold).astype("uint8") * 255

                    # Clean mask
                    kernel = np.ones((3, 3), np.uint8)
                    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
                    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

                    visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

                # ==============================
                # YOLO LABELS
                # ==============================
                if not os.path.exists(label_path):

                    img_h, img_w = mask.shape
                    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                    with open(label_path, "w") as f:
                        for contour in contours:
                            area = cv2.contourArea(contour)
                            if area < 0.001 * img_h * img_w:
                                continue

                            x, y, w, h = cv2.boundingRect(contour)
                            if w < 5 or h < 5:
                                continue

                            x_center = (x + w / 2) / img_w
                            y_center = (y + h / 2) / img_h
                            width = w / img_w
                            height = h / img_h

                            f.write(f"{class_id} {x_center} {y_center} {width} {height}\n")

                # ==============================
                # SAVE UNET MASK
                # ==============================
                mask_path = os.path.join(unet_mask_dir, f"{class_name}_{base_name}.png")
                if not os.path.exists(mask_path):
                    cv2.imwrite(mask_path, mask)

                # ==============================
                # VISUALIZATION
                # ==============================
                mask_color = original_img.copy()
                mask_color[mask == 255] = [255, 0, 0]

                if visualization.dtype != np.uint8:
                    visualization = (visualization * 255).astype(np.uint8)

                combined = np.concatenate(
                    [original_img, visualization, mask_color],
                    axis=1
                )

                cv2.imwrite(save_path, cv2.cvtColor(combined, cv2.COLOR_RGB2BGR))

                # ==============================
                # CLEAN MEMORY
                # ==============================
                del image_tensor, outputs
                torch.cuda.empty_cache()

            except Exception as e:
                print(f"Error processing {img_name}: {e}")

print(f"\n✅ DONE: Processed {counter} images")
# Out:
# train - Tomato__Tomato_YellowLeaf__Curl_Virus: 100%|██████████| 2915/2915 [02:49<00:00, 17.24it/s]
# train - Tomato_Late_blight: 100%|██████████| 1908/1908 [01:42<00:00, 18.54it/s]
# train - Pepper__bell___Bacterial_spot: 100%|██████████| 1500/1500 [01:21<00:00, 18.42it/s]
# train - healthy: 100%|██████████| 5151/5151 [02:04<00:00, 41.48it/s]
# train - Tomato__Tomato_mosaic_virus: 100%|██████████| 1578/1578 [01:28<00:00, 17.81it/s]
# train - Potato___Late_blight: 100%|██████████| 1711/1711 [01:34<00:00, 18.17it/s]
# train - Tomato_Bacterial_spot: 100%|██████████| 1935/1935 [01:53<00:00, 17.03it/s]
# train - Potato___Early_blight: 100%|██████████| 1702/1702 [01:35<00:00, 17.83it/s]
# train - Tomato_Spider_mites_Two_spotted_spider_mite: 100%|██████████| 1848/1848 [01:42<00:00, 18.02it/s]
# train - Tomato__Target_Spot: 100%|██████████| 1796/1796 [01:38<00:00, 18.19it/s]
# train - Tomato_Septoria_leaf_spot: 100%|██████████| 1869/1869 [01:43<00:00, 18.12it/s]
# train - Tomato_Leaf_Mold:  28%|██▊       | 473/1703 [00:26<01:05, 18.91it/s]

# %%
# !zip -r gradcam_results.zip gradcam_results

# %%
from google.colab import files
files.download("gradcam_results.zip")

# %%
# for dataset_dir in gradcam_dirs:
#
#     split = os.path.basename(dataset_dir)   # train or val
#
#     for class_name in os.listdir(dataset_dir):
#
#         class_folder = os.path.join(dataset_dir, class_name)
#
#         if not os.path.isdir(class_folder):
#             continue
#
#         for img_name in tqdm(os.listdir(class_folder), desc=f"{split} - {class_name}"):
#
#             if not img_name.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp')):
#                 continue
#
#             img_path = os.path.join(class_folder, img_name)
#
#             try:
#                 image = Image.open(img_path).convert("RGB")
#
#                 original_img = np.array(image)
#                 original_img = cv2.resize(original_img, (224, 224))
#
#                 # ---------- Leaf Segmentation ----------
#                 leaf, leaf_mask = extract_leaf_mask(original_img)
#
#                 if leaf is None:
#                     continue
#
#                 # Image used for GradCAM visualization
#                 rgb_img = original_img.astype(np.float32) / 255.0
#
#                 # Tensor for model
#                 image_tensor = preprocess_image(Image.fromarray(original_img), train=False).unsqueeze(0).to(device)
#
#                 # ---------- Prediction ----------
#                 outputs = model(image_tensor)
#                 class_id = outputs.argmax(dim=1).item()
#                 targets = [ClassifierOutputTarget(class_id)]
#
#                 is_healthy = "healthy" in class_name.lower()
#                 # ---------- GradCAM ----------
#                 if is_healthy:
#                     mask = leaf_mask
#                 else:
#                     grayscale_cam = cam(input_tensor=image_tensor, targets=targets)
#
#                     if grayscale_cam is None:
#                         continue
#                     try:
#                         grayscale_cam = cam(input_tensor=image_tensor, targets=targets)
#                     except Exception as cam_error:
#                         print("GradCAM failed:", img_name, cam_error)
#                         continue
#
#                     if grayscale_cam is None:
#                         continue
#
#                     # restrict GradCAM to leaf area
#                     grayscale_cam = grayscale_cam * (leaf_mask / 255.0)
#
#                     cam_min = grayscale_cam.min()
#                     cam_max = grayscale_cam.max()
#
#                     if cam_max - cam_min == 0:
#                         continue
#
#                     heatmap_norm = (grayscale_cam - cam_min) / (cam_max - cam_min)
#
#                     threshold = np.percentile(heatmap_norm, 75)
#                     mask = (heatmap_norm >= threshold).astype("uint8") * 255
#
#                     # ---------- Clean Mask ----------
#                     kernel = np.ones((3, 3), np.uint8)
#                     mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
#                     mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
#
#                     img_h, img_w = mask.shape
#
#                     # ---------- Save mask for UNet ----------
#                     mask_dir = "unet_masks"
#                     os.makedirs(mask_dir, exist_ok=True)
#
#                     mask_path = os.path.join(mask_dir, os.path.splitext(img_name)[0] + ".png")
#                     cv2.imwrite(mask_path, mask)
#
#                     mask_color = original_img.copy()
#                     mask_color[mask == 255] = [255, 0, 0]
#
#                     # ---------- Contours ----------
#                     contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#                     contours = sorted(contours, key=cv2.contourArea, reverse=True)[:100]
#
#                     # ---------- YOLO labels ----------
#                     labels_split_dir = os.path.join("Datasets/dataset_yolo2/labels", split)
#                     os.makedirs(labels_split_dir, exist_ok=True)
#
#                     label_path = os.path.join(labels_split_dir, os.path.splitext(img_name)[0] + ".txt")
#
#                     visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)
#
#                     min_area = 0.001 * img_h * img_w
#
#                     with open(label_path, "w") as f:
#
#                         for contour in contours:
#
#                             area = cv2.contourArea(contour)
#
#                             if area < min_area:
#                                 continue
#
#                             x, y, w, h = cv2.boundingRect(contour)
#
#                             if w < 5 or h < 5:
#                                 continue
#
#                             x_center = (x + w / 2) / img_w
#                             y_center = (y + h / 2) / img_h
#                             width = w / img_w
#                             height = h / img_h
#
#                             f.write(f"{class_id} {x_center} {y_center} {width} {height}\n")
#
#                     # ---------- Visualization ----------
#                     combined = np.concatenate([
#                         original_img,
#                         visualization,
#                         mask_color
#                     ], axis=1)
#
#                     os.makedirs(output_dir, exist_ok=True)
#
#                     save_path = os.path.join(output_dir, f"{split}_{class_name}_{img_name}")
#
#                     cv2.imwrite(save_path, cv2.cvtColor(combined, cv2.COLOR_RGB2BGR))
#
#             except Exception as e:
#                 print("Error:", img_name, e)

# %%
# --- Move directory creation OUTSIDE the loops ---
unet_mask_dir = "unet_masks"
yolo_base_dir = "Datasets/dataset_yolo2_generated"
os.makedirs(unet_mask_dir, exist_ok=True)
# Assuming output_dir is defined elsewhere, e.g., output_dir = "visualizations"
os.makedirs(output_dir, exist_ok=True)

for dataset_dir in gradcam_dirs:
    split = os.path.basename(dataset_dir)   # train or val

    yolo_labels_dir = os.path.join(yolo_base_dir, "labels", split)
    yolo_images_dir = os.path.join(yolo_base_dir, "images", split)
    os.makedirs(yolo_labels_dir, exist_ok=True)
    os.makedirs(yolo_images_dir, exist_ok=True)

    for class_name in os.listdir(dataset_dir):
        class_folder = os.path.join(dataset_dir, class_name)

        if not os.path.isdir(class_folder):
            continue

        for img_name in tqdm(os.listdir(class_folder), desc=f"{split} - {class_name}"):
            if not img_name.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp')):
                continue

            img_path = os.path.join(class_folder, img_name)
            base_name = os.path.splitext(img_name)[0]

            try:
                image = Image.open(img_path).convert("RGB")
                original_img = cv2.resize(np.array(image), (224, 224))

                # ---------- Leaf Segmentation ----------
                leaf, leaf_mask = extract_leaf_mask(original_img)
                if leaf is None:
                    continue

                rgb_img = original_img.astype(np.float32) / 255.0
                image_tensor = preprocess_image(Image.fromarray(original_img), train=False).unsqueeze(0).to(device)

                # ---------- Prediction ----------
                outputs = model(image_tensor)
                class_id = outputs.argmax(dim=1).item()
                targets = [ClassifierOutputTarget(class_id)]

                is_healthy = "healthy" in class_name.lower()

                # Copy image to YOLO dataset
                yolo_img_path = os.path.join(yolo_images_dir, img_name)

                # 🔥 SKIP if already processed
                if os.path.exists(yolo_img_path):
                    continue
                cv2.imwrite(yolo_img_path, cv2.cvtColor(original_img, cv2.COLOR_RGB2BGR))

                # Open YOLO label file (will remain empty if healthy)
                label_path = os.path.join(yolo_labels_dir, f"{base_name}.txt")

                if os.path.exists(label_path):
                    continue

                # ---------- Mask Generation ----------
                if is_healthy:
                    mask = leaf_mask
                    visualization = rgb_img

                    img_h, img_w = mask.shape
                    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                    with open(label_path, "w") as f:
                        if contours:
                            largest = max(contours, key=cv2.contourArea)
                            x, y, w, h = cv2.boundingRect(largest)

                            x_center = (x + w / 2) / img_w
                            y_center = (y + h / 2) / img_h
                            width = w / img_w
                            height = h / img_h

                            f.write(f"{class_id} {x_center} {y_center} {width} {height}\n")
                else:
                    try:
                        grayscale_cam = cam(input_tensor=image_tensor, targets=targets)
                    except Exception as cam_error:
                        print(f"GradCAM failed for {img_name}: {cam_error}")
                        continue

                    if grayscale_cam is None:
                        continue

                    # Extract from batch if necessary (shape check)
                    if len(grayscale_cam.shape) == 3:
                        grayscale_cam = grayscale_cam[0]

                    # Restrict GradCAM to leaf area
                    leaf_mask_float = leaf_mask.astype(np.float32) / 255.0
                    grayscale_cam = grayscale_cam * leaf_mask_float

                    cam_min, cam_max = grayscale_cam.min(), grayscale_cam.max()
                    if cam_max - cam_min == 0:
                        continue

                    heatmap_norm = (grayscale_cam - cam_min) / (cam_max - cam_min)
                    threshold = np.percentile(heatmap_norm, 75)
                    mask = (heatmap_norm >= threshold).astype("uint8") * 255

                    # Clean Mask
                    kernel = np.ones((3, 3), np.uint8)
                    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
                    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

                    visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

                    # ---------- YOLO Bounding Boxes ----------
                    img_h, img_w = mask.shape
                    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                    contours = sorted(contours, key=cv2.contourArea, reverse=True)[:100]
                    min_area = 0.001 * img_h * img_w

                    with open(label_path, "w") as f:
                        for contour in contours:
                            area = cv2.contourArea(contour)
                            if area < min_area: continue

                            x, y, w, h = cv2.boundingRect(contour)
                            if w < 5 or h < 5: continue

                            x_center = (x + w / 2) / img_w
                            y_center = (y + h / 2) / img_h
                            width = w / img_w
                            height = h / img_h

                            f.write(f"{class_id} {x_center} {y_center} {width} {height}\n")

                # ---------- Save UNet Mask (For both healthy & diseased) ----------
                mask_path = os.path.join(unet_mask_dir, f"{class_name}_{base_name}.png")
                cv2.imwrite(mask_path, mask)

                # ---------- Final Visualization ----------
                mask_color = original_img.copy()
                mask_color[mask == 255] = [255, 0, 0]

                # Convert visualization to uint8 if it isn't already
                if visualization.dtype != np.uint8:
                    visualization = (visualization * 255).astype(np.uint8)

                combined = np.concatenate([original_img, visualization, mask_color], axis=1)
                save_path = os.path.join(output_dir, f"{split}_{class_name}_{img_name}")
                cv2.imwrite(save_path, cv2.cvtColor(combined, cv2.COLOR_RGB2BGR))

            except Exception as e:
                print(f"Error processing {img_name}: {e}")
